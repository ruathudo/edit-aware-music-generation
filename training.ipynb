# %%
import os
import tensorflow as tf
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import random
import copy
# Out:
# 2026-03-11 12:21:01.346902: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-11 12:21:01.384639: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-11 12:21:02.175980: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/qduong/Projects/MusicEditLearning/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
test_path = "data/test/*.tfrecord"
# train_path = "data/train/*.tfrecord"
val_path = "data/validation/*.tfrecord"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def parse_seq_example(example_proto):
    # Define how to parse
    context_features = {
    }

    sequence_features = {
        "pitch_seq": tf.io.VarLenFeature(dtype=tf.int64),
    }
    _, sequence = tf.io.parse_single_sequence_example(
        example_proto,
        context_features=context_features,
        sequence_features=sequence_features
    )
    pitch_seq = tf.sparse.to_dense(sequence["pitch_seq"])
    pitch_seq = tf.reshape(pitch_seq, [-1])
    return pitch_seq

# Create dataset
# dataset = tf.data.TFRecordDataset(tf.io.gfile.glob(tfrecord_path))
# dataset = dataset.map(parse_seq_example)

# %%
# Inspect first example
# for seq in dataset.take(1):
#     print(seq.numpy())

# %%
def pitch_seq_to_notes(pitch_seq):
    notes = []
    i = 0
    while i < len(pitch_seq):
        token = pitch_seq[i]
        if token == 128:
            # hold token without a preceding note — skip
            i += 1
            continue
        if token == 129:
            # rest — skip or treat as durationless rest
            i += 1
            continue

        # Otherwise, this is a real note onset
        pitch = int(token)
        duration = 1
        j = i + 1
        # Count holds
        while j < len(pitch_seq) and pitch_seq[j] == 128:
            duration += 1
            j += 1

        notes.append((pitch, duration))
        i = j

    return notes

# %%
# notes = pitch_seq_to_notes(seq.numpy())
# print(notes)

# %%
PITCH_MIN = 21
PITCH_MAX = 108
DURATIONS = [1, 2, 3, 4, 6, 8] 

SPECIAL_TOKENS = ["<PAD>", "<BOS>", "<EOS>"]

pitch_tokens = [f"P{p}" for p in range(PITCH_MIN, PITCH_MAX + 1)]
duration_tokens = [f"D{d}" for d in DURATIONS]

vocab = SPECIAL_TOKENS + pitch_tokens + duration_tokens

token_to_id = {tok: i for i, tok in enumerate(vocab)}
id_to_token = {i: tok for tok, i in token_to_id.items()}

PAD_ID = token_to_id["<PAD>"]
BOS_ID = token_to_id["<BOS>"]
EOS_ID = token_to_id["<EOS>"]

# %%
def melody_is_valid(notes):
    return all(d in DURATIONS for _, d in notes)


def notes_to_tokens(notes, edited_note_indices=None):
    tokens = [BOS_ID]
    # mask = [0]

    for i, (pitch, dur) in enumerate(notes):
        tokens.append(token_to_id[f"P{pitch}"])
        tokens.append(token_to_id[f"D{dur}"])

        # is_edited = edited_note_indices and i in edited_note_indices
        # mask.extend([1 if is_edited else 0, 1 if is_edited else 0])

    tokens.append(EOS_ID)
    # mask.append(0)
    return tokens #mask



EDIT_TYPES = ["replace_pitch", "change_duration", "delete_note", "insert_note"]

def sample_edit_type():
    """Samples an edit type from EDIT_TYPES."""
    # p=[0.4, 0.2, 0.2, 0.2]
    return np.random.choice(EDIT_TYPES, p=[0.4, 0.3, 0.15, 0.15])

def sample_position(melody, edit_type):
    """Samples a valid position for a given edit type."""
    if edit_type == "insert_note":
        # Can insert at the end
        return random.randint(0, len(melody))

    return random.randint(0, len(melody) - 1)

def sample_duration(exclude_duration):
    """Samples a duration from DURATIONS, excluding exclude_duration."""
    new_durations = [d for d in DURATIONS if d != exclude_duration]
    if not new_durations:
        return exclude_duration
    return random.choice(new_durations)

def sample_insert_note():
    """Samples a random note to insert."""
    pitch = random.randint(PITCH_MIN, PITCH_MAX)
    duration = random.choice(DURATIONS)
    return (pitch, duration)

def simulate_edits(melody, max_edits=5):
    melody_corrupt = copy.deepcopy(melody)
    edit_script = []

    n_edits = random.randint(1, max_edits)

    for _ in range(n_edits):
        edit_type = sample_edit_type()

        if edit_type == "insert_note":
            t = sample_position(melody_corrupt, edit_type)
            note = sample_insert_note()
            melody_corrupt.insert(t, note)
            edit_script.append(("delete_note", t))
        elif len(melody_corrupt) == 0: # No other edits possible on empty melody
            continue
        else:
            t = sample_position(melody_corrupt, edit_type)
            if edit_type == "replace_pitch":
                old_p, d = melody_corrupt[t]
                # Make sure new pitch is different and within bounds
                new_p = old_p
                while new_p == old_p:
                    new_p = old_p + random.choice([-2, -1, 1, 2])
                    new_p = max(PITCH_MIN, min(PITCH_MAX, new_p))

                melody_corrupt[t] = (new_p, d)
                edit_script.append(("replace_pitch", t, old_p))

            elif edit_type == "change_duration":
                p, old_d = melody_corrupt[t]
                new_d = sample_duration(old_d)
                melody_corrupt[t] = (p, new_d)
                edit_script.append(("change_duration", t, old_d))

            elif edit_type == "delete_note":
                note = melody_corrupt.pop(t)
                edit_script.append(("insert_note", t, note))

    return melody_corrupt, edit_script


def build_edit_mask(
    corrupted_tokens,
    edit_script,
    pad_id,
):
    """
    Build a binary edit mask aligned with corrupted_tokens.

    Args:
        corrupted_tokens: List[int] (already padded)
        edit_script: list of edit operations
        pad_id: PAD token id

    Returns:
        mask: List[int] same length as corrupted_tokens
    """
    L = len(corrupted_tokens)
    mask = [0] * L

    for edit in edit_script:
        etype = edit[0]

        if etype == "replace_pitch":
            t = edit[1]
            pitch_idx = 1 + 2 * t
            if pitch_idx < L:
                mask[pitch_idx] = 1

        elif etype == "change_duration":
            t = edit[1]
            dur_idx = 1 + 2 * t + 1
            if dur_idx < L:
                mask[dur_idx] = 1

        elif etype == "delete_note":
            t = edit[1]
            pitch_idx = 1 + 2 * t
            dur_idx = pitch_idx + 1
            if pitch_idx < L:
                mask[pitch_idx] = 1
            if dur_idx < L:
                mask[dur_idx] = 1

        elif etype == "insert_note":
            t = edit[1]
            # insertion affects *neighboring context*
            # mark next note as editable (simple & stable)
            pitch_idx = 1 + 2 * t
            if pitch_idx < L:
                mask[pitch_idx] = 1
                if pitch_idx + 1 < L:
                    mask[pitch_idx + 1] = 1

    # Never penalize PAD tokens
    for i in range(L):
        if corrupted_tokens[i] == pad_id:
            mask[i] = 0

    return mask


def decode_tokens(tokens, id_to_token):
    return [id_to_token[t] if t in id_to_token else "PAD" for t in tokens]

def visualize_edit_mask(tokens, mask, id_to_token):
    decoded = decode_tokens(tokens, id_to_token)
    print("Idx | Token | Mask")
    print("-" * 25)
    for i, (tok, m) in enumerate(zip(decoded, mask)):
        flag = "⬅️" if m == 1 else ""
        print(f"{i:3d} | {tok:6s} | {int(m)} {flag}")

# %%
def collate_fn(batch):
    corrupted, clean, edit_scripts = zip(*batch)

    corrupted = pad_sequence(corrupted, batch_first=True, padding_value=PAD_ID)
    clean = pad_sequence(clean, batch_first=True, padding_value=PAD_ID)

    edit_masks = []
    for tokens, script in zip(corrupted, edit_scripts):
        mask = build_edit_mask(tokens.tolist(), script, PAD_ID)
        edit_masks.append(mask)

    edit_masks = torch.tensor(edit_masks, dtype=torch.float)
    # masks = pad_sequence(masks, batch_first=True, padding_value=0)

    # print((corrupted == PAD_ID).sum())
    # print((clean == PAD_ID).sum())

    return corrupted, clean, edit_masks, edit_scripts


class MelodyDataset(Dataset):
    def __init__(self, tfrecord_path):
        self.dataset = tf.data.TFRecordDataset(tf.io.gfile.glob(tfrecord_path))
        self.dataset = self.dataset.map(parse_seq_example)
        self.samples = []

        for pitch_seq in self.dataset:
            notes = pitch_seq_to_notes(pitch_seq.numpy())
            if len(notes) > 0 and melody_is_valid(notes):
                self.samples.append(notes)

    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        original_notes = self.samples[idx]
        corrupted_notes, edit_script = simulate_edits(original_notes)
        
        # edited_positions = {e[1] for e in edit_script if len(e) > 1}

        corrupted_tokens = notes_to_tokens(corrupted_notes)
        original_tokens = notes_to_tokens(original_notes)

        
        return (
            torch.tensor(corrupted_tokens, dtype=torch.long),
            torch.tensor(original_tokens, dtype=torch.long),
            # torch.tensor(edit_mask, dtype=torch.long),
            edit_script
        )

# %%
# train_dataset = MelodyDataset(train_path)
val_dataset = MelodyDataset(val_path)
test_dataset = MelodyDataset(test_path)

# print(f"Train Dataset size: {len(train_dataset)}")
print(f"Val Dataset size: {len(val_dataset)}")
print(f"Test Dataset size: {len(test_dataset)}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773224472.196807  893204 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22006 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2026-03-11 12:21:12.459798: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:390] TFRecordDataset `buffer_size` is unspecified, default to 262144
# 2026-03-11 12:21:15.303833: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Val Dataset size: 44984
# Test Dataset size: 13957
# 2026-03-11 12:21:16.215063: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
test_dataset[3]
# Out:
# (tensor([ 1, 54, 92, 42, 92, 53, 93, 46, 95, 53, 91, 54, 91, 54, 93, 88, 93, 46,
#          91, 51, 92, 51, 92, 53, 92, 54, 91, 56, 93, 53, 92,  2]),
#  tensor([ 1, 54, 92, 42, 92, 53, 93, 46, 95, 53, 91, 54, 91, 54, 93, 46, 91, 51,
#          92, 51, 92, 53, 92, 54, 91, 56, 93, 53, 92,  2]),
#  [('delete_note', 7)])

# %%
def tokens_to_notes(tokens, id_to_token):
    """
    tokens: List[int]
    returns: List[(pitch, duration)]
    """
    notes = []
    i = 0

    while i < len(tokens):
        tok = id_to_token[tokens[i]]

        if tok == "<BOS>" or tok == "<EOS>" or tok == "<PAD>":
            i += 1
            continue

        if tok.startswith("P"):
            pitch = int(tok[1:])
            if i + 1 < len(tokens):
                dur_tok = id_to_token[tokens[i + 1]]
                if dur_tok.startswith("D"):
                    duration = int(dur_tok[1:])
                    notes.append((pitch, duration))
                    i += 2
                else:
                    i += 1
            else:
                i += 1
        else:
            i += 1

    return notes

INSERT_COST = 1
DELETE_COST = 1

def note_replace_cost(n1, n2):
    """
    n1, n2: (pitch, duration)
    """
    cost = 0
    if n1[0] != n2[0]:
        cost += 1  # pitch change
    if n1[1] != n2[1]:
        cost += 1  # duration change
    return cost


def minimal_edit_distance(pred_notes, ref_notes):
    """
    pred_notes: List[(pitch, duration)]
    ref_notes:  List[(pitch, duration)]
    returns: total_cost, edit_counts
    """

    N = len(pred_notes)
    M = len(ref_notes)

    # DP table
    dp = [[0] * (M + 1) for _ in range(N + 1)]

    # Initialize
    for i in range(1, N + 1):
        dp[i][0] = i * DELETE_COST
    for j in range(1, M + 1):
        dp[0][j] = j * INSERT_COST

    # Fill table
    for i in range(1, N + 1):
        for j in range(1, M + 1):
            delete = dp[i - 1][j] + DELETE_COST
            insert = dp[i][j - 1] + INSERT_COST
            replace = dp[i - 1][j - 1] + note_replace_cost(
                pred_notes[i - 1],
                ref_notes[j - 1]
            )
            dp[i][j] = min(delete, insert, replace)

    # Backtrace for edit statistics
    i, j = N, M
    edits = {
        "insert": 0,
        "delete": 0,
        "replace_pitch": 0,
        "replace_duration": 0
    }

    while i > 0 or j > 0:
        current = dp[i][j]

        if i > 0 and current == dp[i - 1][j] + DELETE_COST:
            edits["delete"] += 1
            i -= 1

        elif j > 0 and current == dp[i][j - 1] + INSERT_COST:
            edits["insert"] += 1
            j -= 1

        else:
            # replace or match
            p, d = pred_notes[i - 1]
            rp, rd = ref_notes[j - 1]

            if p != rp:
                edits["replace_pitch"] += 1
            if d != rd:
                edits["replace_duration"] += 1

            i -= 1
            j -= 1

    return dp[N][M], edits



def paired_edit_improvement(baseline_costs: np.ndarray, editaware_costs: np.ndarray):
    """
    Args:
        baseline_costs: list of (total_cost, cost_per_note) tuples
        editaware_costs: list of (total_cost, cost_per_note) tuples

    Returns:
        dict of paired statistics
    """
    deltas = []

    baseline_sample_costs = baseline_costs[:, 0]
    editaware_sample_costs = editaware_costs[:, 0]
    deltas = baseline_sample_costs - editaware_sample_costs

    stats = {
        "mean_delta": float(deltas.mean()),
        "median_delta": float(np.median(deltas)),
        "std_delta": float(deltas.std()),
        "pct_improved": float((deltas > 0).mean() * 100),
        "pct_worse": float((deltas < 0).mean() * 100),
        "pct_equal": float((deltas == 0).mean() * 100),
        "baseline_mean_cost": float(np.mean(baseline_costs)),
        "editaware_mean_cost": float(np.mean(editaware_costs)),
    }

    return stats


def compare_cost_per_note(baseline_costs: np.ndarray, editaware_costs: np.ndarray):
    baseline_norm = baseline_costs[:, 1]
    editaware_norm = editaware_costs[:, 1]
    deltas = baseline_norm - editaware_norm

    return {
        "baseline_mean": float(baseline_norm.mean()),
        "editaware_mean": float(editaware_norm.mean()),
        "mean_delta": float(deltas.mean()),
        "median_delta": float(np.median(deltas)),
        "pct_improved": float((deltas > 0).mean() * 100),
    }

def calculate_edit_cost(pred_tokens, ref_tokens):
    """
    pred_tokens: List[List[(pitch, duration)]]
    ref_tokens:  List[List[(pitch, duration)]]
    returns: total_cost
    """
    total_cost = 0

    for p, r in zip(pred_tokens, ref_tokens):
        pred_notes = tokens_to_notes(p, id_to_token)
        ref_notes = tokens_to_notes(r, id_to_token)

        cost, _ = minimal_edit_distance(pred_notes, ref_notes)
        # costs_per_note = cost / max(len(ref_notes), 1)
        total_cost += cost

    return total_cost


def evaluate_model(model, dataloader, edit_loss=True):
    model.eval()
    total_cost = 0
    stats = defaultdict(int)
    sample_costs = []

    for corrupted, clean, _, _ in dataloader:
        corrupted = corrupted.to(device)
        clean = clean.to(device)

        with torch.no_grad():
            # Teacher forcing
            inputs = corrupted[:, :-1]
            targets = clean[:, 1:]

            T = min(inputs.size(1), targets.size(1))

            inputs = inputs[:, :T]
            targets = targets[:, :T]

            if edit_loss:
                logits, _ = model(inputs)
            else:
                logits = model(inputs)

            pred_tokens = torch.argmax(logits, dim=-1).cpu().numpy()
            ref_tokens = targets.cpu().numpy()

            # print(ref_tokens.shape, pred_tokens.shape)
            # print(inputs.shape, pred_tokens.shape, len(pred_notes), len(ref_notes))

            for p, r in zip(pred_tokens, ref_tokens):
                pred_notes = tokens_to_notes(p, id_to_token)
                ref_notes = tokens_to_notes(r, id_to_token)
                # print(f"Predicted: {p}, Reference: {r}")
                cost, edit_counts = minimal_edit_distance(pred_notes, ref_notes)
                costs_per_note = cost / max(len(ref_notes), 1)
                sample_costs.append([cost, costs_per_note])

                total_cost += cost

                for k, v in edit_counts.items():
                    stats[k] += v

    return total_cost, stats, np.array(sample_costs)

# %%
# Create DataLoader
batch_size = 32
# train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# Example of how to use the dataloader
# for corrupted_batch, clean_batch, masks_batch, edit_script_batch in train_dataloader:
#    print(f"Corrupted batch shape: {corrupted_batch.shape}")
#    print(f"Clean batch shape: {clean_batch.shape}")
#    print(f"Masks batch shape: {masks_batch.shape}")
#    print(f"Edit script batch (first item): {edit_script_batch[0]}")
#    break

# %%
def causal_mask(size, device):
    return torch.triu(
        torch.ones(size, size, device=device), diagonal=1
    ).bool()


class MelodyTransformer(nn.Module):

    def __init__(
        self,
        vocab_size,
        d_model=256,
        n_heads=4,
        n_layers=4,
        use_edit_head=False
    ):
        super().__init__()

        self.use_edit_head = use_edit_head

        self.embed = nn.Embedding(vocab_size, d_model, padding_idx=PAD_ID)
        self.pos_embed = nn.Embedding(512, d_model)

        decoder_layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=n_heads,
            batch_first=True
        )

        self.decoder = nn.TransformerDecoder(decoder_layer, n_layers)

        # token prediction head (baseline)
        self.fc = nn.Linear(d_model, vocab_size)

        # optional edit head
        if self.use_edit_head:
            self.edit_head = nn.Linear(d_model, 1)

    def forward(self, x):

        B, T = x.shape

        pos = torch.arange(T, device=x.device).unsqueeze(0).expand(B, T)

        mask = causal_mask(T, x.device)

        x = self.embed(x) + self.pos_embed(pos)

        h = self.decoder(x, x, tgt_mask=mask)

        token_logits = self.fc(h)

        if not self.use_edit_head:
            return token_logits

        edit_logits = self.edit_head(h).squeeze(-1)

        return token_logits, edit_logits

# %%
def train_baseline(
    model,
    train_dataloader,
    val_dataloader,
    optimizer,
    device=device,
    epochs=10,
    patience=5,
    min_improvement=1e-3
):
    """
    Train baseline model with early stopping to prevent overfitting.
    
    Args:
        model: The model to train
        train_dataloader: Training data loader
        val_dataloader: Validation data loader
        optimizer: Optimizer
        device: Device to train on
        epochs: Maximum number of epochs
        patience: Number of epochs with no improvement before stopping
        min_improvement: Minimum improvement threshold for validation loss
    """
    print(f"Training on device: {device}")
    criterion = nn.CrossEntropyLoss(ignore_index=PAD_ID)
    
    baseline_loss = defaultdict(list)
    # Early stopping variables
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for corrupted, clean, _, _ in train_dataloader:
            corrupted = corrupted.to(device)
            clean = clean.to(device)

            # Teacher forcing
            inputs = corrupted[:, :-1]
            targets = clean[:, 1:]

            T = min(inputs.size(1), targets.size(1))

            inputs = inputs[:, :T].to(device)
            targets = targets[:, :T].to(device)

            logits = model(inputs)

            loss = criterion(
                logits.reshape(-1, logits.size(-1)),
                targets.reshape(-1)
            )

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_dataloader)
        print(f"[Baseline] Epoch {epoch+1}: loss = {avg_loss:.4f}")

        # Validation
        model.eval()
        val_loss = 0.0
        val_edit_cost = 0.0
        
        with torch.no_grad():
            for corrupted, clean, _, _ in val_dataloader:
                corrupted = corrupted.to(device)
                clean = clean.to(device)

                inputs = corrupted[:, :-1]
                targets = clean[:, 1:]

                T = min(inputs.size(1), targets.size(1))

                inputs = inputs[:, :T]
                targets = targets[:, :T]

                logits = model(inputs)

                loss = criterion(
                    logits.reshape(-1, logits.size(-1)),
                    targets.reshape(-1)
                )

                pred_tokens = torch.argmax(logits, dim=-1).cpu().numpy()
                ref_tokens = targets.cpu().numpy()

                val_loss += loss.item()
                val_edit_cost += calculate_edit_cost(pred_tokens, ref_tokens)


        avg_val_loss = val_loss / len(val_dataloader)
        avg_val_edit_cost = val_edit_cost / len(val_dataloader)
        print(f"[Validation] Epoch {epoch+1}: loss = {avg_val_loss:.4f}, edit_cost = {avg_val_edit_cost:.4f}")
        
        baseline_loss['train'].append(avg_loss)
        baseline_loss['val'].append(avg_val_loss)
        
        # Early stopping logic
        # if best_val_loss - avg_val_loss > min_improvement:
        if best_val_loss - avg_val_loss > min_improvement:
            # Significant improvement detected
            best_val_loss = avg_val_loss
            patience_counter = 0
            best_model_state = model.state_dict().copy()
            print(f"Validation loss improved to {avg_val_loss:.4f}")
        else:
            # No significant improvement
            patience_counter += 1
            print(f"No improvement. Patience: {patience_counter}/{patience}")
            
            if patience_counter >= patience:
                print(f"\nEarly stopping triggered! Validation loss did not improve for {patience} epochs.")
                print(f"Best validation loss: {best_val_loss:.4f}")
                
                # Restore best model
                if best_model_state is not None:
                    model.load_state_dict(best_model_state)
                    print("Restored best model weights.")
                break
    return baseline_loss

# %%
# batch = next(iter(test_dataloader))
# print(batch[0].shape, batch[1].shape)

criterion = nn.CrossEntropyLoss(ignore_index=PAD_ID)
model = MelodyTransformer(vocab_size=len(vocab), d_model=256, n_heads=4, n_layers=4).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
# Save trained model
# torch.save(model.state_dict(), os.path.join("models", "baseline.pth"))

# load saved model
# model.load_state_dict(torch.load(os.path.join("models", "baseline.pth")))

# %%
baseline_loss = train_baseline(model, val_dataloader, test_dataloader, optimizer, epochs=50, patience=5, min_improvement=1e-3)
# Out:
# Training on device: cuda
# [Baseline] Epoch 1: loss = 0.9435
# [Validation] Epoch 1: loss = 0.5956, edit_cost = 196.2838
# Validation loss improved to 0.5956
# [Baseline] Epoch 2: loss = 0.5845
# [Validation] Epoch 2: loss = 0.5526, edit_cost = 174.3112
# Validation loss improved to 0.5526
# [Baseline] Epoch 3: loss = 0.5498
# [Validation] Epoch 3: loss = 0.5252, edit_cost = 167.9108
# Validation loss improved to 0.5252
# [Baseline] Epoch 4: loss = 0.5312
# [Validation] Epoch 4: loss = 0.5184, edit_cost = 141.6796
# Validation loss improved to 0.5184
# [Baseline] Epoch 5: loss = 0.5210
# [Validation] Epoch 5: loss = 0.4992, edit_cost = 159.0503
# Validation loss improved to 0.4992
# [Baseline] Epoch 6: loss = 0.5022
# [Validation] Epoch 6: loss = 0.4810, edit_cost = 147.8719
# Validation loss improved to 0.4810
# [Baseline] Epoch 7: loss = 0.4899
# [Validation] Epoch 7: loss = 0.4706, edit_cost = 168.8169
# Validation loss improved to 0.4706
# [Baseline] Epoch 8: loss = 0.4808
# [Validation] Epoch 8: loss = 0.4667, edit_cost = 146.4851
# Validation loss improved to 0.4667
# [Baseline] Epoch 9: loss = 0.4717
# [Validation] Epoch 9: loss = 0.4586, edit_cost = 136.3158
# Validation loss improved to 0.4586
# [Baseline] Epoch 10: loss = 0.4649
# [Validation] Epoch 10: loss = 0.4476, edit_cost = 132.6888
# Validation loss improved to 0.4476
# [Baseline] Epoch 11: loss = 0.4607
# [Validation] Epoch 11: loss = 0.4537, edit_cost = 125.1327
# No improvement. Patience: 1/5
# [Baseline] Epoch 12: loss = 0.4615
# [Validation] Epoch 12: loss = 0.4484, edit_cost = 125.1693
# No improvement. Patience: 2/5
# [Baseline] Epoch 13: loss = 0.4543
# [Validation] Epoch 13: loss = 0.4402, edit_cost = 131.6636
# Validation loss improved to 0.4402
# [Baseline] Epoch 14: loss = 0.4505
# [Validation] Epoch 14: loss = 0.4445, edit_cost = 125.5835
# No improvement. Patience: 1/5
# [Baseline] Epoch 15: loss = 0.4476
# [Validation] Epoch 15: loss = 0.4398, edit_cost = 125.3913
# No improvement. Patience: 2/5
# [Baseline] Epoch 16: loss = 0.4450
# [Validation] Epoch 16: loss = 0.4415, edit_cost = 127.3112
# No improvement. Patience: 3/5
# [Baseline] Epoch 17: loss = 0.4406
# [Validation] Epoch 17: loss = 0.4329, edit_cost = 117.4188
# Validation loss improved to 0.4329
# [Baseline] Epoch 18: loss = 0.4402
# [Validation] Epoch 18: loss = 0.4373, edit_cost = 121.5515
# No improvement. Patience: 1/5
# [Baseline] Epoch 19: loss = 0.4371
# [Validation] Epoch 19: loss = 0.4317, edit_cost = 120.6842
# Validation loss improved to 0.4317
# [Baseline] Epoch 20: loss = 0.4337
# [Validation] Epoch 20: loss = 0.4275, edit_cost = 114.5400
# Validation loss improved to 0.4275
# [Baseline] Epoch 21: loss = 0.4366
# [Validation] Epoch 21: loss = 0.4256, edit_cost = 127.1762
# Validation loss improved to 0.4256
# [Baseline] Epoch 22: loss = 0.4312
# [Validation] Epoch 22: loss = 0.4249, edit_cost = 119.1716
# No improvement. Patience: 1/5
# [Baseline] Epoch 23: loss = 0.4306
# [Validation] Epoch 23: loss = 0.4217, edit_cost = 115.9130
# Validation loss improved to 0.4217
# [Baseline] Epoch 24: loss = 0.4301
# [Validation] Epoch 24: loss = 0.4243, edit_cost = 117.3661
# No improvement. Patience: 1/5
# [Baseline] Epoch 25: loss = 0.4288
# [Validation] Epoch 25: loss = 0.4228, edit_cost = 110.9474
# No improvement. Patience: 2/5
# [Baseline] Epoch 26: loss = 0.4254
# [Validation] Epoch 26: loss = 0.4209, edit_cost = 115.6407
# No improvement. Patience: 3/5
# [Baseline] Epoch 27: loss = 0.4271
# [Validation] Epoch 27: loss = 0.4179, edit_cost = 122.7208
# Validation loss improved to 0.4179
# [Baseline] Epoch 28: loss = 0.4242
# [Validation] Epoch 28: loss = 0.4198, edit_cost = 114.5332
# No improvement. Patience: 1/5
# [Baseline] Epoch 29: loss = 0.4202
# [Validation] Epoch 29: loss = 0.4124, edit_cost = 114.1327
# Validation loss improved to 0.4124
# [Baseline] Epoch 30: loss = 0.4201
# [Validation] Epoch 30: loss = 0.4193, edit_cost = 120.2426
# No improvement. Patience: 1/5
# [Baseline] Epoch 31: loss = 0.4187
# [Validation] Epoch 31: loss = 0.4114, edit_cost = 112.3844
# No improvement. Patience: 2/5
# [Baseline] Epoch 32: loss = 0.4191
# [Validation] Epoch 32: loss = 0.4184, edit_cost = 114.4622
# No improvement. Patience: 3/5
# [Baseline] Epoch 33: loss = 0.4185
# [Validation] Epoch 33: loss = 0.4231, edit_cost = 114.7803
# No improvement. Patience: 4/5
# [Baseline] Epoch 34: loss = 0.4149
# [Validation] Epoch 34: loss = 0.4109, edit_cost = 109.6796
# Validation loss improved to 0.4109
# [Baseline] Epoch 35: loss = 0.4149
# [Validation] Epoch 35: loss = 0.4211, edit_cost = 113.6041
# No improvement. Patience: 1/5
# [Baseline] Epoch 36: loss = 0.4127
# [Validation] Epoch 36: loss = 0.4165, edit_cost = 115.6979
# No improvement. Patience: 2/5
# [Baseline] Epoch 37: loss = 0.4156
# [Validation] Epoch 37: loss = 0.4174, edit_cost = 111.6339
# No improvement. Patience: 3/5
# [Baseline] Epoch 38: loss = 0.4108
# [Validation] Epoch 38: loss = 0.4136, edit_cost = 115.2197
# No improvement. Patience: 4/5
# [Baseline] Epoch 39: loss = 0.4134
# [Validation] Epoch 39: loss = 0.4108, edit_cost = 111.4211
# No improvement. Patience: 5/5
#
# Early stopping triggered! Validation loss did not improve for 5 epochs.
# Best validation loss: 0.4109
# Restored best model weights.

# %%
# train_baseline(model, val_dataloader, test_dataloader, optimizer, epochs=10)

# %%
baseline_total_cost, baseline_stats, baseline_sample_costs = evaluate_model(model, test_dataloader)
print(f"Total edit cost on training set: {baseline_total_cost}")
print(f"Edit statistics: {dict(baseline_stats)}")
# Out:
# Total edit cost on training set: 48836
# Edit statistics: {'insert': 9273, 'delete': 6566, 'replace_pitch': 22829, 'replace_duration': 10168}

# %%
def edit_weighted_loss(
    token_logits,      # (B, T, V)
    target_tokens,     # (B, T)
    edit_logits,       # (B, T)
    edit_masks,        # (B, T)
    corrupted_tokens,  # (B, T)
    pad_id = PAD_ID,
    alpha=1.0
):
    """
    Multi-task edit-aware loss.

    token_logits: model token predictions
    edit_logits: model edit predictions
    edit_masks: ground truth edit mask (0/1)

    Returns:
        scalar loss
    """

    B, T, V = token_logits.shape

    # --------------------------------------------------
    # Token prediction loss
    # --------------------------------------------------

    token_loss = F.cross_entropy(
        token_logits.reshape(B * T, V),
        target_tokens.reshape(B * T),
        ignore_index=pad_id
    )

    # --------------------------------------------------
    # Edit prediction loss
    # --------------------------------------------------

    # valid tokens (exclude padding)
    valid_mask = corrupted_tokens != pad_id   # (B, T)

    # select valid positions
    edit_logits_valid = edit_logits[valid_mask]
    edit_targets_valid = edit_masks.float()[valid_mask]

    edit_loss = F.binary_cross_entropy_with_logits(
        edit_logits_valid,
        edit_targets_valid
    )

    # --------------------------------------------------
    # Combined loss
    # --------------------------------------------------

    loss = token_loss + alpha * edit_loss

    return loss


def train_edit_aware(
    model,
    train_dataloader,
    val_dataloader,
    optimizer,
    device=device,
    alpha=1.0,
    epochs=10,
    patience=5,
    min_improvement=1e-3
):
    edit_aware_loss = defaultdict(list)
    # Early stopping variables
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    for epoch in range(epochs):
        total_loss = 0.0
        model.train()

        for corrupted, clean, edit_mask, _ in train_dataloader:
            corrupted = corrupted.to(device)
            clean = clean.to(device)
            edit_mask = edit_mask.to(device)

            inputs = corrupted[:, :-1]
            targets = clean[:, 1:]
            mask = edit_mask[:, 1:]

            T = min(inputs.size(1), targets.size(1), mask.size(1))

            inputs = inputs[:, :T]
            targets = targets[:, :T]
            mask = mask[:, :T]

            logits, edit_logits = model(inputs)

            loss = edit_weighted_loss(
                logits,
                targets,
                edit_logits,
                mask,
                inputs,
                pad_id=PAD_ID,
                alpha=alpha,
            )

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_dataloader)
        print(f"[Edit-aware α={alpha}] Epoch {epoch+1}: loss = {avg_loss:.4f}")

        # Validation
        model.eval()
        val_loss = 0.0
        val_edit_cost = 0.0
        with torch.no_grad():
            for corrupted, clean, edit_mask, _ in val_dataloader:
                corrupted = corrupted.to(device)
                clean = clean.to(device)
                edit_mask = edit_mask.to(device)

                inputs = corrupted[:, :-1]
                targets = clean[:, 1:]
                mask = edit_mask[:, 1:]

                T = min(inputs.size(1), targets.size(1), mask.size(1))

                inputs = inputs[:, :T]
                targets = targets[:, :T]
                mask = mask[:, :T]

                logits, edit_logits = model(inputs)

                # print(inputs.shape)
                # print(logits.shape)
                # print(edit_logits.shape)
                # print(mask.shape)

                loss = edit_weighted_loss(
                    logits,
                    targets,
                    edit_logits,
                    mask,
                    inputs,
                    pad_id=PAD_ID,
                    alpha=alpha,
                )

                pred_tokens = torch.argmax(logits, dim=-1).cpu().numpy()
                ref_tokens = targets.cpu().numpy()

                val_loss += loss.item()
                val_edit_cost += calculate_edit_cost(pred_tokens, ref_tokens)


        avg_val_loss = val_loss / len(val_dataloader)
        avg_val_edit_cost = val_edit_cost / len(val_dataloader)
        print(f"[Validation] Epoch {epoch+1}: loss = {avg_val_loss:.4f}, edit_cost = {avg_val_edit_cost:.2f}")

        edit_aware_loss['train'].append(avg_loss)
        edit_aware_loss['val'].append(avg_val_loss)

                # Early stopping logic
        if best_val_loss - avg_val_loss > min_improvement:
            # Significant improvement detected
            best_val_loss = avg_val_loss
            patience_counter = 0
            best_model_state = model.state_dict().copy()
            print(f"Validation loss improved to {avg_val_loss:.4f}")
        else:
            # No significant improvement
            patience_counter += 1
            print(f"No improvement. Patience: {patience_counter}/{patience}")
            
            if patience_counter >= patience:
                print(f"\nEarly stopping triggered! Validation loss did not improve for {patience} epochs.")
                print(f"Best validation loss: {best_val_loss:.4f}")
                
                # Restore best model
                if best_model_state is not None:
                    model.load_state_dict(best_model_state)
                    print("Restored best model weights.")
                break

    return edit_aware_loss

# %%
edit_aware_model = MelodyTransformer(use_edit_head=True, vocab_size=len(vocab), d_model=256, n_heads=4, n_layers=4).to(device)
edit_are_optimizer = torch.optim.Adam(edit_aware_model.parameters(), lr=0.0001)

# %%
edit_aware_loss = train_edit_aware(edit_aware_model, val_dataloader, test_dataloader, edit_are_optimizer, 
                                   alpha=0.5, epochs=100, patience=5, min_improvement=1e-3)
# Out:
# [Edit-aware α=0.5] Epoch 1: loss = 1.0611
# [Validation] Epoch 1: loss = 0.6942, edit_cost = 179.69
# Validation loss improved to 0.6942
# [Edit-aware α=0.5] Epoch 2: loss = 0.6861
# [Validation] Epoch 2: loss = 0.6445, edit_cost = 164.51
# Validation loss improved to 0.6445
# [Edit-aware α=0.5] Epoch 3: loss = 0.6476
# [Validation] Epoch 3: loss = 0.6278, edit_cost = 143.78
# Validation loss improved to 0.6278
# [Edit-aware α=0.5] Epoch 4: loss = 0.6256
# [Validation] Epoch 4: loss = 0.5997, edit_cost = 145.09
# Validation loss improved to 0.5997
# [Edit-aware α=0.5] Epoch 5: loss = 0.6104
# [Validation] Epoch 5: loss = 0.5784, edit_cost = 157.35
# Validation loss improved to 0.5784
# [Edit-aware α=0.5] Epoch 6: loss = 0.5923
# [Validation] Epoch 6: loss = 0.5677, edit_cost = 157.26
# Validation loss improved to 0.5677
# [Edit-aware α=0.5] Epoch 7: loss = 0.5805
# [Validation] Epoch 7: loss = 0.5655, edit_cost = 146.48
# Validation loss improved to 0.5655
# [Edit-aware α=0.5] Epoch 8: loss = 0.5711
# [Validation] Epoch 8: loss = 0.5514, edit_cost = 131.54
# Validation loss improved to 0.5514
# [Edit-aware α=0.5] Epoch 9: loss = 0.5625
# [Validation] Epoch 9: loss = 0.5497, edit_cost = 129.00
# Validation loss improved to 0.5497
# [Edit-aware α=0.5] Epoch 10: loss = 0.5544
# [Validation] Epoch 10: loss = 0.5377, edit_cost = 135.60
# Validation loss improved to 0.5377
# [Edit-aware α=0.5] Epoch 11: loss = 0.5474
# [Validation] Epoch 11: loss = 0.5314, edit_cost = 127.56
# Validation loss improved to 0.5314
# [Edit-aware α=0.5] Epoch 12: loss = 0.5457
# [Validation] Epoch 12: loss = 0.5306, edit_cost = 136.83
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 13: loss = 0.5405
# [Validation] Epoch 13: loss = 0.5231, edit_cost = 122.45
# Validation loss improved to 0.5231
# [Edit-aware α=0.5] Epoch 14: loss = 0.5342
# [Validation] Epoch 14: loss = 0.5238, edit_cost = 115.97
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 15: loss = 0.5322
# [Validation] Epoch 15: loss = 0.5208, edit_cost = 119.92
# Validation loss improved to 0.5208
# [Edit-aware α=0.5] Epoch 16: loss = 0.5297
# [Validation] Epoch 16: loss = 0.5139, edit_cost = 114.81
# Validation loss improved to 0.5139
# [Edit-aware α=0.5] Epoch 17: loss = 0.5242
# [Validation] Epoch 17: loss = 0.5061, edit_cost = 115.95
# Validation loss improved to 0.5061
# [Edit-aware α=0.5] Epoch 18: loss = 0.5218
# [Validation] Epoch 18: loss = 0.5116, edit_cost = 114.08
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 19: loss = 0.5202
# [Validation] Epoch 19: loss = 0.5081, edit_cost = 119.36
# No improvement. Patience: 2/5
# [Edit-aware α=0.5] Epoch 20: loss = 0.5228
# [Validation] Epoch 20: loss = 0.5061, edit_cost = 120.50
# No improvement. Patience: 3/5
# [Edit-aware α=0.5] Epoch 21: loss = 0.5141
# [Validation] Epoch 21: loss = 0.5103, edit_cost = 111.74
# No improvement. Patience: 4/5
# [Edit-aware α=0.5] Epoch 22: loss = 0.5123
# [Validation] Epoch 22: loss = 0.5004, edit_cost = 113.09
# Validation loss improved to 0.5004
# [Edit-aware α=0.5] Epoch 23: loss = 0.5152
# [Validation] Epoch 23: loss = 0.5147, edit_cost = 110.77
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 24: loss = 0.5100
# [Validation] Epoch 24: loss = 0.5055, edit_cost = 108.65
# No improvement. Patience: 2/5
# [Edit-aware α=0.5] Epoch 25: loss = 0.5124
# [Validation] Epoch 25: loss = 0.5078, edit_cost = 116.62
# No improvement. Patience: 3/5
# [Edit-aware α=0.5] Epoch 26: loss = 0.5077
# [Validation] Epoch 26: loss = 0.5057, edit_cost = 113.08
# No improvement. Patience: 4/5
# [Edit-aware α=0.5] Epoch 27: loss = 0.5065
# [Validation] Epoch 27: loss = 0.4961, edit_cost = 114.83
# Validation loss improved to 0.4961
# [Edit-aware α=0.5] Epoch 28: loss = 0.5073
# [Validation] Epoch 28: loss = 0.4985, edit_cost = 110.11
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 29: loss = 0.5045
# [Validation] Epoch 29: loss = 0.4930, edit_cost = 119.54
# Validation loss improved to 0.4930
# [Edit-aware α=0.5] Epoch 30: loss = 0.4979
# [Validation] Epoch 30: loss = 0.4923, edit_cost = 107.48
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 31: loss = 0.5032
# [Validation] Epoch 31: loss = 0.4936, edit_cost = 117.51
# No improvement. Patience: 2/5
# [Edit-aware α=0.5] Epoch 32: loss = 0.5008
# [Validation] Epoch 32: loss = 0.4978, edit_cost = 109.27
# No improvement. Patience: 3/5
# [Edit-aware α=0.5] Epoch 33: loss = 0.4998
# [Validation] Epoch 33: loss = 0.4940, edit_cost = 116.28
# No improvement. Patience: 4/5
# [Edit-aware α=0.5] Epoch 34: loss = 0.4967
# [Validation] Epoch 34: loss = 0.4917, edit_cost = 111.11
# Validation loss improved to 0.4917
# [Edit-aware α=0.5] Epoch 35: loss = 0.4979
# [Validation] Epoch 35: loss = 0.4916, edit_cost = 109.05
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 36: loss = 0.4948
# [Validation] Epoch 36: loss = 0.4884, edit_cost = 108.03
# Validation loss improved to 0.4884
# [Edit-aware α=0.5] Epoch 37: loss = 0.4961
# [Validation] Epoch 37: loss = 0.4927, edit_cost = 120.01
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 38: loss = 0.4904
# [Validation] Epoch 38: loss = 0.4861, edit_cost = 109.97
# Validation loss improved to 0.4861
# [Edit-aware α=0.5] Epoch 39: loss = 0.4921
# [Validation] Epoch 39: loss = 0.4891, edit_cost = 111.96
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 40: loss = 0.4907
# [Validation] Epoch 40: loss = 0.4866, edit_cost = 109.43
# No improvement. Patience: 2/5
# [Edit-aware α=0.5] Epoch 41: loss = 0.4888
# [Validation] Epoch 41: loss = 0.4894, edit_cost = 113.72
# No improvement. Patience: 3/5
# [Edit-aware α=0.5] Epoch 42: loss = 0.4887
# [Validation] Epoch 42: loss = 0.4851, edit_cost = 110.64
# Validation loss improved to 0.4851
# [Edit-aware α=0.5] Epoch 43: loss = 0.4895
# [Validation] Epoch 43: loss = 0.4812, edit_cost = 106.53
# Validation loss improved to 0.4812
# [Edit-aware α=0.5] Epoch 44: loss = 0.4873
# [Validation] Epoch 44: loss = 0.4876, edit_cost = 108.62
# No improvement. Patience: 1/5
# [Edit-aware α=0.5] Epoch 45: loss = 0.4868
# [Validation] Epoch 45: loss = 0.4969, edit_cost = 108.14
# No improvement. Patience: 2/5
# [Edit-aware α=0.5] Epoch 46: loss = 0.4841
# [Validation] Epoch 46: loss = 0.4840, edit_cost = 115.14
# No improvement. Patience: 3/5
# [Edit-aware α=0.5] Epoch 47: loss = 0.4818
# [Validation] Epoch 47: loss = 0.4814, edit_cost = 113.41
# No improvement. Patience: 4/5
# [Edit-aware α=0.5] Epoch 48: loss = 0.4853
# [Validation] Epoch 48: loss = 0.4866, edit_cost = 112.30
# No improvement. Patience: 5/5
#
# Early stopping triggered! Validation loss did not improve for 5 epochs.
# Best validation loss: 0.4812
# Restored best model weights.

# %%
# Impelemnt the visualization of training and validation loss here
def visualize_loss(loss_dict):


    epochs = range(1, len(loss_dict['train']) + 1)

    plt.plot(epochs, loss_dict['train'], label='Training Loss')
    plt.plot(epochs, loss_dict['val'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.show()

# %%
visualize_loss(baseline_loss)

# %%
visualize_loss(edit_aware_loss)

# %%
# alpha = 0.7
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 46852
# Edit statistics: {'insert': 8501, 'delete': 7118, 'replace_pitch': 21400, 'replace_duration': 9833}

# %%
# alpha = 0.5
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 48848
# Edit statistics: {'insert': 9296, 'delete': 6616, 'replace_pitch': 22268, 'replace_duration': 10668}

# %%
# alpha = 1
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 45859
# Edit statistics: {'insert': 8868, 'delete': 6261, 'replace_pitch': 21169, 'replace_duration': 9561}

# %%
# alpha = 0.3
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 48763
# Edit statistics: {'insert': 9184, 'delete': 6934, 'replace_pitch': 22475, 'replace_duration': 10170}

# %%
# alpha = 0
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 47330
# Edit statistics: {'insert': 8551, 'delete': 6835, 'replace_pitch': 22087, 'replace_duration': 9857}

# %%
# alpha = 0.5
total_cost, stats, edit_sample_costs = evaluate_model(edit_aware_model, test_dataloader)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 49369
# Edit statistics: {'insert': 9124, 'delete': 7755, 'replace_pitch': 22050, 'replace_duration': 10440}

# %%
total_cost, stats, baseline_sample_costs = evaluate_model(model, test_dataloader, edit_loss=False)
print(f"Total edit cost on test set: {total_cost}")
print(f"Edit statistics: {dict(stats)}")
# Out:
# Total edit cost on test set: 48327
# Edit statistics: {'insert': 8684, 'delete': 7077, 'replace_pitch': 22603, 'replace_duration': 9963}

# %%
improvement = paired_edit_improvement(baseline_sample_costs, edit_sample_costs)
cost_per_note = compare_cost_per_note(baseline_sample_costs, edit_sample_costs)

print("\nPaired Edit Improvement:", improvement)
print("\nCost Per Note:", cost_per_note)
# Out:
# Paired Edit Improvement: {'mean_delta': -0.032036613272311214, 'median_delta': 0.0, 'std_delta': 2.9440050738899335, 'pct_improved': 40.73226544622426, 'pct_worse': 40.274599542334094, 'pct_equal': 18.993135011441648, 'baseline_mean_cost': 1.7735316660562903, 'editaware_mean_cost': 1.7894893595993446}
#
# Cost Per Note: {'baseline_mean': 0.13287568909198538, 'editaware_mean': 0.13275446290578338, 'mean_delta': 0.00012122618620198635, 'median_delta': 0.0, 'pct_improved': 40.73226544622426}

# %%
import random
print(random.randint(1, 1))
# Out:
# 1
